# %%
#%tensorflow_version 1.x
from time import time
from scipy.sparse import csc_matrix
import tensorflow as tf
import numpy as np
import h5py

# %%
print(tf.__version__)
# Out:
# 1.15.0

# %% [markdown]
# # Data Loader Function

# %%
def load_data_100k(path='./', delimiter='\t'):

    train = np.loadtxt(path+'movielens_100k_u1.base', skiprows=0, delimiter=delimiter).astype('int32')
    test = np.loadtxt(path+'movielens_100k_u1.test', skiprows=0, delimiter=delimiter).astype('int32')
    total = np.concatenate((train, test), axis=0)

    n_u = np.unique(total[:,0]).size  # num of users
    n_m = np.unique(total[:,1]).size  # num of movies
    n_train = train.shape[0]  # num of training ratings
    n_test = test.shape[0]  # num of test ratings

    train_r = np.zeros((n_m, n_u), dtype='float32')
    test_r = np.zeros((n_m, n_u), dtype='float32')

    for i in range(n_train):
        train_r[train[i,1]-1, train[i,0]-1] = train[i,2]

    for i in range(n_test):
        test_r[test[i,1]-1, test[i,0]-1] = test[i,2]

    train_m = np.greater(train_r, 1e-12).astype('float32')  # masks indicating non-zero entries
    test_m = np.greater(test_r, 1e-12).astype('float32')

    print('data matrix loaded')
    print('num of users: {}'.format(n_u))
    print('num of movies: {}'.format(n_m))
    print('num of training ratings: {}'.format(n_train))
    print('num of test ratings: {}'.format(n_test))

    return n_m, n_u, train_r, train_m, test_r, test_m

# %%
def load_data_1m(path='./', delimiter='::', frac=0.1, seed=1234):

    tic = time()
    print('reading data...')
    data = np.loadtxt(path+'movielens_1m_dataset.dat', skiprows=0, delimiter=delimiter).astype('int32')
    print('taken', time() - tic, 'seconds')

    n_u = np.unique(data[:,0]).size  # num of users
    n_m = np.unique(data[:,1]).size  # num of movies
    n_r = data.shape[0]  # num of ratings

    udict = {}
    for i, u in enumerate(np.unique(data[:,0]).tolist()):
        udict[u] = i
    mdict = {}
    for i, m in enumerate(np.unique(data[:,1]).tolist()):
        mdict[m] = i

    np.random.seed(seed)
    idx = np.arange(n_r)
    np.random.shuffle(idx)

    train_r = np.zeros((n_m, n_u), dtype='float32')
    test_r = np.zeros((n_m, n_u), dtype='float32')

    for i in range(n_r):
        u_id = data[idx[i], 0]
        m_id = data[idx[i], 1]
        r = data[idx[i], 2]

        if i < int(frac * n_r):
            test_r[mdict[m_id], udict[u_id]] = r
        else:
            train_r[mdict[m_id], udict[u_id]] = r

    train_m = np.greater(train_r, 1e-12).astype('float32')  # masks indicating non-zero entries
    test_m = np.greater(test_r, 1e-12).astype('float32')

    print('data matrix loaded')
    print('num of users: {}'.format(n_u))
    print('num of movies: {}'.format(n_m))
    print('num of training ratings: {}'.format(n_r - int(frac * n_r)))
    print('num of test ratings: {}'.format(int(frac * n_r)))

    return n_m, n_u, train_r, train_m, test_r, test_m

# %%
def load_matlab_file(path_file, name_field):
    
    db = h5py.File(path_file, 'r')
    ds = db[name_field]

    try:
        if 'ir' in ds.keys():
            data = np.asarray(ds['data'])
            ir   = np.asarray(ds['ir'])
            jc   = np.asarray(ds['jc'])
            out  = csc_matrix((data, ir, jc)).astype(np.float32)
    except AttributeError:
        out = np.asarray(ds).astype(np.float32).T

    db.close()

    return out

# %%
def load_data_monti(path='./'):

    M = load_matlab_file(path+'douban_monti_dataset.mat', 'M')
    Otraining = load_matlab_file(path+'douban_monti_dataset.mat', 'Otraining') * M
    Otest = load_matlab_file(path+'douban_monti_dataset.mat', 'Otest') * M

    n_u = M.shape[0]  # num of users
    n_m = M.shape[1]  # num of movies
    n_train = Otraining[np.where(Otraining)].size  # num of training ratings
    n_test = Otest[np.where(Otest)].size  # num of test ratings

    train_r = Otraining.T
    test_r = Otest.T

    train_m = np.greater(train_r, 1e-12).astype('float32')  # masks indicating non-zero entries
    test_m = np.greater(test_r, 1e-12).astype('float32')

    print('data matrix loaded')
    print('num of users: {}'.format(n_u))
    print('num of movies: {}'.format(n_m))
    print('num of training ratings: {}'.format(n_train))
    print('num of test ratings: {}'.format(n_test))

    return n_m, n_u, train_r, train_m, test_r, test_m

# %% [markdown]
# # Load Data

# %%
# Insert the path of a data directory by yourself (e.g., '/content/.../data')
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
data_path = r'C:\Users\MMSETUBAL\Documents\Glocal_K-main\data'
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._

# %%
# Select a dataset among 'ML-1M', 'ML-100K', and 'Douban'
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
dataset = 'ML-100K'
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._

# %%
# Data Load
try:
    if dataset == 'ML-100K':
        path = data_path + '/MovieLens_100K/'
        n_m, n_u, train_r, train_m, test_r, test_m = load_data_100k(path=path, delimiter='\t')

    elif dataset == 'ML-1M':
        path = data_path + '/MovieLens_1M/'
        n_m, n_u, train_r, train_m, test_r, test_m = load_data_1m(path=path, delimiter='::', frac=0.1, seed=1234)

    elif dataset == 'Douban':
        path = data_path + '/Douban_monti/'
        n_m, n_u, train_r, train_m, test_r, test_m = load_data_monti(path=path)

    else:
        raise ValueError

except ValueError:
    print('Error: Unable to load data')
# Out:
# data matrix loaded
# num of users: 943
# num of movies: 1682
# num of training ratings: 80000
# num of test ratings: 20000

# %% [markdown]
# # Hyperparameter Settings

# %%
# Common hyperparameter settings
n_hid = 500
n_dim = 5
n_layers = 2
gk_size = 3

# %%
# Different hyperparameter settings for each dataset
if dataset == 'ML-100K':
    lambda_2 = 20.  # l2 regularisation
    lambda_s = 0.006
    iter_p = 5  # optimisation
    iter_f = 5
    epoch_p = 30  # training epoch
    epoch_f = 60
    dot_scale = 1  # scaled dot product

elif dataset == 'ML-1M':
    lambda_2 = 70.
    lambda_s = 0.018
    iter_p = 50
    iter_f = 10
    epoch_p = 20
    epoch_f = 30
    dot_scale = 0.5

elif dataset == 'Douban':
    lambda_2 = 10.
    lambda_s = 0.022
    iter_p = 5
    iter_f = 5
    epoch_p = 20
    epoch_f = 60
    dot_scale = 2

# %%
R = tf.placeholder("float", [n_m, n_u])
# Out:
# WARNING:tensorflow:From C:\Users\MMSETUBAL\AppData\Local\Temp\ipykernel_7396\2682195965.py:1: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %% [markdown]
# # Network Function

# %%
def local_kernel(u, v):

    dist = tf.norm(u - v, ord=2, axis=2)
    hat = tf.maximum(0., 1. - dist**2)

    return hat

# %%
def kernel_layer(x, n_hid=n_hid, n_dim=n_dim, activation=tf.nn.sigmoid, lambda_s=lambda_s, lambda_2=lambda_2, name=''):

    with tf.variable_scope(name, reuse=tf.AUTO_REUSE):
        W = tf.get_variable('W', [x.shape[1], n_hid])
        n_in = x.get_shape().as_list()[1]
        u = tf.get_variable('u', initializer=tf.random.truncated_normal([n_in, 1, n_dim], 0., 1e-3))
        v = tf.get_variable('v', initializer=tf.random.truncated_normal([1, n_hid, n_dim], 0., 1e-3))
        b = tf.get_variable('b', [n_hid])

    w_hat = local_kernel(u, v)
    
    sparse_reg = tf.contrib.layers.l2_regularizer(lambda_s)
    sparse_reg_term = tf.contrib.layers.apply_regularization(sparse_reg, [w_hat])
    
    l2_reg = tf.contrib.layers.l2_regularizer(lambda_2)
    l2_reg_term = tf.contrib.layers.apply_regularization(l2_reg, [W])

    W_eff = W * w_hat  # Local kernelised weight matrix
    y = tf.matmul(x, W_eff) + b
    y = activation(y)

    return y, sparse_reg_term + l2_reg_term

# %%
def global_kernel(input, gk_size, dot_scale):

    avg_pooling = tf.reduce_mean(input, axis=1)  # Item (axis=1) based average pooling
    avg_pooling = tf.reshape(avg_pooling, [1, -1])
    n_kernel = avg_pooling.shape[1].value

    conv_kernel = tf.get_variable('conv_kernel', initializer=tf.random.truncated_normal([n_kernel, gk_size**2], stddev=0.1))
    gk = tf.matmul(avg_pooling, conv_kernel) * dot_scale  # Scaled dot product
    gk = tf.reshape(gk, [gk_size, gk_size, 1, 1])

    return gk

# %%
def global_conv(input, W):

    input = tf.reshape(input, [1, input.shape[0], input.shape[1], 1])
    conv2d = tf.nn.relu(tf.nn.conv2d(input, W, strides=[1,1,1,1], padding='SAME'))

    return tf.reshape(conv2d, [conv2d.shape[1], conv2d.shape[2]])

# %% [markdown]
# # Network Instantiation

# %% [markdown]
# ## Pre-training

# %%
y = R
reg_losses = None

for i in range(n_layers):
    y, reg_loss = kernel_layer(y, name=str(i))
    reg_losses = reg_loss if reg_losses is None else reg_losses + reg_loss

pred_p, reg_loss = kernel_layer(y, n_u, activation=tf.identity, name='out')
reg_losses = reg_losses + reg_loss

# L2 loss
diff = train_m * (train_r - pred_p)
sqE = tf.nn.l2_loss(diff)
loss_p = sqE + reg_losses

optimizer_p = tf.contrib.opt.ScipyOptimizerInterface(loss_p, options={'disp': True, 'maxiter': iter_p, 'maxcor': 10}, method='L-BFGS-B')
# Out:
# WARNING:tensorflow:From C:\Users\MMSETUBAL\AppData\Local\Temp\ipykernel_7396\1127187019.py:3: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\MMSETUBAL\AppData\Local\Temp\ipykernel_7396\1127187019.py:3: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From C:\Users\MMSETUBAL\AppData\Local\Temp\ipykernel_7396\1127187019.py:4: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From C:\Users\MMSETUBAL\Anaconda3\envs\tf1\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# ## Fine-tuning

# %%
y = R
reg_losses = None

for i in range(n_layers):
    y, _ = kernel_layer(y, name=str(i))

y_dash, _ = kernel_layer(y, n_u, activation=tf.identity, name='out')

gk = global_kernel(y_dash, gk_size, dot_scale)  # Global kernel
y_hat = global_conv(train_r, gk)  # Global kernel-based rating matrix

for i in range(n_layers):
    y_hat, reg_loss = kernel_layer(y_hat, name=str(i))
    reg_losses = reg_loss if reg_losses is None else reg_losses + reg_loss

pred_f, reg_loss = kernel_layer(y_hat, n_u, activation=tf.identity, name='out')
reg_losses = reg_losses + reg_loss

# L2 loss
diff = train_m * (train_r - pred_f)
sqE = tf.nn.l2_loss(diff)
loss_f = sqE + reg_losses

optimizer_f = tf.contrib.opt.ScipyOptimizerInterface(loss_f, options={'disp': True, 'maxiter': iter_f, 'maxcor': 10}, method='L-BFGS-B')

# %% [markdown]
# # Evaluation code

# %%
def dcg_k(score_label, k):
    dcg, i = 0., 0
    for s in score_label:
        if i < k:
            dcg += (2**s[1]-1) / np.log2(2+i)
            i += 1
    return dcg

# %%
def ndcg_k(y_hat, y, k):
    score_label = np.stack([y_hat, y], axis=1).tolist()
    score_label = sorted(score_label, key=lambda d:d[0], reverse=True)
    score_label_ = sorted(score_label, key=lambda d:d[1], reverse=True)
    norm, i = 0., 0
    for s in score_label_:
        if i < k:
            norm += (2**s[1]-1) / np.log2(2+i)
            i += 1
    dcg = dcg_k(score_label, k)
    return dcg / norm

# %%
def call_ndcg(y_hat, y):
    ndcg_sum, num = 0, 0
    y_hat, y = y_hat.T, y.T
    n_users = y.shape[0]

    for i in range(n_users):
        y_hat_i = y_hat[i][np.where(y[i])]
        y_i = y[i][np.where(y[i])]

        if y_i.shape[0] < 2:
            continue

        ndcg_sum += ndcg_k(y_hat_i, y_i, y_i.shape[0])  # user-wise calculation
        num += 1

    return ndcg_sum / num

# %% [markdown]
# # Training and Test Loop

# %%
best_rmse_ep, best_mae_ep, best_ndcg_ep, best_TP_ep, best_FP_ep = 0, 0, 0, 0, 0
best_rmse, best_mae, best_ndcg, best_TP, best_FP = float("inf"), float("inf"), 0, 0, float('inf')

time_cumulative = 0
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for i in range(epoch_p):
        tic = time()
        optimizer_p.minimize(sess, feed_dict={R: train_r})
        pre = sess.run(pred_p, feed_dict={R: train_r})

        t = time() - tic
        time_cumulative += t
        
        error = (test_m * (np.clip(pre, 1., 5.) - test_r) ** 2).sum() / test_m.sum()  # test error
        test_rmse = np.sqrt(error)

        error_train = (train_m * (np.clip(pre, 1., 5.) - train_r) ** 2).sum() / train_m.sum()  # train error
        train_rmse = np.sqrt(error_train)

        print('.-^-._' * 12)
        print('PRE-TRAINING')
        print('Epoch:', i+1, 'test rmse:', test_rmse, 'train rmse:', train_rmse)
        print('Time:', t, 'seconds')
        print('Time cumulative:', time_cumulative, 'seconds')
        print('.-^-._' * 12)

    for i in range(epoch_f):
        tic = time()
        optimizer_f.minimize(sess, feed_dict={R: train_r})
        pre = sess.run(pred_f, feed_dict={R: train_r})
        pre_m = np.copy(pre)
        pre_m[pre>=3] = 1
        pre_m[pre<3]  = 0

        t = time() - tic
        time_cumulative += t
        
        error = (test_m * (np.clip(pre, 1., 5.) - test_r) ** 2).sum() / test_m.sum()  # test error
        test_rmse = np.sqrt(error)

        error_train = (train_m * (np.clip(pre, 1., 5.) - train_r) ** 2).sum() / train_m.sum()  # train error
        train_rmse = np.sqrt(error_train)

        test_mae = (test_m * np.abs(np.clip(pre, 1., 5.) - test_r)).sum() / test_m.sum()
        train_mae = (train_m * np.abs(np.clip(pre, 1., 5.) - train_r)).sum() / train_m.sum()

        test_ndcg = call_ndcg(np.clip(pre, 1., 5.), test_r)
        train_ndcg = call_ndcg(np.clip(pre, 1., 5.), train_r)
        
        true  = pre_m[np.any(test_m.astype(dtype=bool))]==test_m
        false = pre_m[np.any(test_m.astype(dtype=bool))]!=test_m
        test_TP = np.sum(true[0][pre_m==1])
        test_FP = np.sum(false[0][pre_m==1])

        if test_rmse < best_rmse:
            best_rmse = test_rmse
            best_rmse_ep = i+1

        if test_mae < best_mae:
            best_mae = test_mae
            best_mae_ep = i+1
            
        if test_TP > best_TP:
            best_TP = test_TP
            best_TP_ep = i+1
        
        if test_FP < best_FP:
            best_FP = test_FP
            best_FP_ep = i+1

        if best_ndcg < test_ndcg:
            best_ndcg = test_ndcg
            best_ndcg_ep = i+1

        print('.-^-._' * 12)
        print('FINE-TUNING')
        print('Epoch:', i+1, 'test rmse:', test_rmse, 'test mae:', test_mae, 'test ndcg:', test_ndcg)
        print('Epoch:', i+1, 'test TP:', test_TP, 'test FP', test_FP)
        print('Epoch:', i+1, 'train rmse:', train_rmse, 'train mae:', train_mae, 'train ndcg:', train_ndcg)
        print('Time:', t, 'seconds')
        print('Time cumulative:', time_cumulative, 'seconds')
        print('.-^-._' * 12)
# Out:
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 86400.046875
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 1 test rmse: 1.418786 train rmse: 1.2602996
# Time: 4.075263738632202 seconds
# Time cumulative: 4.075263738632202 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 62856.148438
#   Number of iterations: 5
#   Number of functions evaluations: 6
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 2 test rmse: 1.0774912 train rmse: 1.0115305
# Time: 3.1393136978149414 seconds
# Time cumulative: 7.2145774364471436 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 60592.210938
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 3 test rmse: 1.0298592 train rmse: 0.9860474
# Time: 3.1193697452545166 seconds
# Time cumulative: 10.33394718170166 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 59305.402344
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 4 test rmse: 1.0111811 train rmse: 0.97124785
# Time: 3.064664602279663 seconds
# Time cumulative: 13.398611783981323 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 57481.980469
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 5 test rmse: 0.9919088 train rmse: 0.9524438
# Time: 3.5189223289489746 seconds
# Time cumulative: 16.917534112930298 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 56724.238281
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch:
seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 35760.992188
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 21 test rmse: 0.8922192 test mae: 0.6977571 test ndcg: 0.9028617580943096
# Epoch: 21 test TP: 15314 test FP 873502
# Epoch: 21 train rmse: 0.7477199 train mae: 0.58631563 train ndcg: 0.9374467546288122
# Time: 5.895717620849609 seconds
# Time cumulative: 244.10898351669312 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 35577.796875
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 22 test rmse: 0.8919936 test mae: 0.69848377 test ndcg: 0.903526128818656
# Epoch: 22 test TP: 15335 test FP 862118
# Epoch: 22 train rmse: 0.7455707 train mae: 0.5846183 train ndcg: 0.9379712605768463
# Time: 5.516153573989868 seconds
# Time cumulative: 249.62513709068298 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 35424.968750
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 23 test rmse: 0.8909462 test mae: 0.6970519 test ndcg: 0.9031819865517208
# Epoch: 23 test TP: 15325 test FP 867798
# Epoch: 23 train rmse: 0.7437128 train mae: 0.5831538 train ndcg: 0.9382139277383392
# Time: 5.887360095977783 seconds
# Time cumulative: 255.51249718666077 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 35212.328125
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 24 test rmse: 0.89504725 test mae: 0.7008741 test ndcg: 0.9038237139635276
# Epoch: 24 test TP: 15330 test FP 852234
# Epoch: 24 train rmse: 0.7424224 train mae: 0.5820683 train ndcg: 0.9395423445431839
# Time: 5.800479888916016 seconds
# Time cumulative: 261.3129770755768 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 34943.609375
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 25 test rmse: 0.89126986 test mae: 0.69695467 test ndcg: 0.9035970757688182
# Epoch: 25 test TP: 15312 test FP 865311
# Epoch: 25 train rmse: 0.73838407 train mae: 0.5786573 train ndcg: 0.939597556212138
# Time: 5.5991370677948 seconds
# Time cumulative: 266.9121141433716 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 34790.878906
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 26 test rmse: 0.8916413 test mae: 0.6978072 test ndcg: 0.9040292790652865
# Epoch: 26 test TP: 15303 test FP 854961
# Epoch: 26 train rmse: 0.73678786 train mae: 0.5776221 train ndcg: 0.9401510613144892
# Time: 5.784865856170654 seconds
# Time cumulative: 272.69697999954224 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 34647.773438
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 27 test rmse: 0.8912505 test mae: 0.69693667 test ndcg: 0.9042659881782579
# Epoch: 27 test TP: 15289 test FP 862243
# Epoch: 27 train rmse: 0.7351084 train mae: 0.5761027 train ndcg: 0.9407512441012064
# Time: 5.728973627090454 seconds
# Time cumulative: 278.4259536266327 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 34512.757812
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 28 test rmse: 0.89178354 test mae: 0.69807786 test ndcg: 0.9044271963606269
# Epoch: 28 test TP: 15291 test FP 851477
# Epoch: 28 train rmse: 0.7336008 train mae: 0.5750221 train ndcg: 0.9411813149901289
# Time: 6.1890952587127686 seconds
# Time cumulative: 284.61504888534546 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 34379.648438
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 29 test rmse: 0.89105695 test mae: 0.69668835 test ndcg: 0.904344954655439
# Epoch: 29 test TP: 15291 test FP 860330
# Epoch: 29 train rmse: 0.73197526 train mae: 0.5735534 train ndcg: 0.9414662700240688
# Time: 6.264643669128418 seconds
# Time cumulative: 290.8796925544739 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 34259.789062
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 30 test rmse: 0.8915904 test mae: 0.6977698 test ndcg: 0.9039575401577364
# Epoch: 30 test TP: 15286 test FP 849547
# Epoch: 30 train rmse: 0.73064476 train mae: 0.57264215 train ndcg: 0.9416024242283708
# Time: 5.665154695510864 seconds
# Time cumulative: 296.54484724998474 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 34141.433594
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 31 test rmse: 0.89101475 test mae: 0.6966569 test ndcg: 0.9044672618240959
# Epoch: 31 test TP: 15271 test FP 857327
# Epoch: 31 train rmse: 0.72917676 train mae: 0.5713514 train ndcg: 0.9419173399706239
# Time: 5.625927686691284 seconds
# Time cumulative: 302.170774936676 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 34021.898438
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 32 test rmse: 0.8913343 test mae: 0.6973561 test ndcg: 0.9040752619245276
# Epoch: 32 test TP: 15288 test FP 848723
# Epoch: 32 train rmse: 0.72796726 train mae: 0.5706148 train ndcg: 0.9421063333680595
# Time: 5.8390843868255615 seconds
# Time cumulative: 308.0098593235016 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 33909.312500
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 33 test rmse: 0.89120704 test mae: 0.69682425 test ndcg: 0.9046803312828686
# Epoch: 33 test TP: 15258 test FP 855037
# Epoch: 33 train rmse: 0.72652125 train mae: 0.5692586 train ndcg: 0.9424794405112878
# Time: 5.64221715927124 seconds
# Time cumulative: 313.6520764827728 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 33801.925781
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 34 test rmse: 0.8910834 test mae: 0.6971385 test ndcg: 0.9043138304309034
# Epoch: 34 test TP: 15247 test FP 848883
# Epoch: 34 train rmse: 0.7251744 train mae: 0.56834465 train ndcg: 0.9426252838497162
# Time: 5.722436189651489 seconds
# Time cumulative: 319.3745126724243 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 33654.359375
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 35 test rmse: 0.8908744 test mae: 0.6963273 test ndcg: 0.9036265405247854
# Epoch: 35 test TP: 15269 test FP 851530
# Epoch: 35 train rmse: 0.7236295 train mae: 0.56695807 train ndcg: 0.9432351194484235
# Time: 5.746150732040405 seconds
# Time cumulative: 325.1206634044647 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 33551.187500
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 36 test rmse: 0.891933 test mae: 0.6980123 test ndcg: 0.9039493327663486
# Epoch: 36 test TP: 15229 test FP 845003
# Epoch: 36 train rmse: 0.7223737 train mae: 0.5661153 train ndcg: 0.9436658732473818
# Time: 5.692294597625732 seconds
# Time cumulative: 330.81295800209045 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 33446.488281
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 37 test rmse: 0.89094585 test mae: 0.6964637 test ndcg: 0.9041354841529461
# Epoch: 37 test TP: 15252 test FP 848420
# Epoch: 37 train rmse: 0.7209563 train mae: 0.5647845 train ndcg: 0.9438709838819017
# Time: 5.6983864307403564 seconds
# Time cumulative: 336.5113444328308 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 33343.312500
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 38 test rmse: 0.89191747 test mae: 0.6980333 test ndcg: 0.9042525868790946
# Epoch: 38 test TP: 15216 test FP 843030
# Epoch: 38 train rmse: 0.71986127 train mae: 0.5641101 train ndcg: 0.9440366918768783
# Time: 6.026338815689087 seconds
# Time cumulative: 342.5376832485199 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 33244.898438
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 39 test rmse: 0.890939 test mae: 0.6964423 test ndcg: 0.9043525514180818
# Epoch: 39 test TP: 15240 test FP 846845
# Epoch: 39 train rmse: 0.71849453 train mae: 0.56277496 train ndcg: 0.9443173017327586
# Time: 5.674456357955933 seconds
# Time cumulative: 348.21213960647583 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 33134.523438
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 40 test rmse: 0.8921917 test mae: 0.69834 test ndcg: 0.9043329681426575
# Epoch: 40 test TP: 15193 test FP 840474
# Epoch: 40 train rmse: 0.7173655 train mae: 0.5622151 train ndcg: 0.94430206362994
# Time: 5.738395929336548 seconds
# Time cumulative: 353.9505355358124 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 33014.683594
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 41 test rmse: 0.8911671 test mae: 0.6966028 test ndcg: 0.9049128677466143
# Epoch: 41 test TP: 15220 test FP 844927
# Epoch: 41 train rmse: 0.7157215 train mae: 0.5607388 train ndcg: 0.9447846099966631
# Time: 6.0901939868927 seconds
# Time cumulative: 360.0407295227051 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 32844.031250
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 42 test rmse: 0.8929937 test mae: 0.69883305 test ndcg: 0.9045512530280743
# Epoch: 42 test TP: 15169 test FP 834594
# Epoch: 42 train rmse: 0.7140209 train mae: 0.55932045 train ndcg: 0.9451771382660921
# Time: 5.909134387969971 seconds
# Time cumulative: 365.94986391067505 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 32714.378906
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 43 test rmse: 0.89102894 test mae: 0.6967999 test ndcg: 0.9045880911426158
# Epoch: 43 test TP: 15210 test FP 840662
# Epoch: 43 train rmse: 0.7120779 train mae: 0.5578458 train ndcg: 0.9453788766828071
# Time: 5.89615535736084 seconds
# Time cumulative: 371.8460192680359 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 32641.990234
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 44 test rmse: 0.8911348 test mae: 0.69671535 test ndcg: 0.9050968301069793
# Epoch: 44 test TP: 15218 test FP 841069
# Epoch: 44 train rmse: 0.7112236 train mae: 0.5571695 train ndcg: 0.9456675075562396
# Time: 5.761875629425049 seconds
# Time cumulative: 377.60789489746094 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 32578.878906
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 45 test rmse: 0.89115334 test mae: 0.69736534 test ndcg: 0.905040227479177
# Epoch: 45 test TP: 15190 test FP 838362
# Epoch: 45 train rmse: 0.71067446 train mae: 0.5570349 train ndcg: 0.9459732591618769
# Time: 5.784006834030151 seconds
# Time cumulative: 383.3919017314911 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 32471.521484
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 46 test rmse: 0.8913957 test mae: 0.69663817 test ndcg: 0.9048599786979225
# Epoch: 46 test TP: 15196 test FP 839527
# Epoch: 46 train rmse: 0.7090179 train mae: 0.55533314 train ndcg: 0.9460579145203
# Time: 5.375636339187622 seconds
# Time cumulative: 388.7675380706787 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 32366.433594
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 47 test rmse: 0.8916446 test mae: 0.69734514 test ndcg: 0.9048672476677235
# Epoch: 47 test TP: 15175 test FP 838923
# Epoch: 47 train rmse: 0.70763236 train mae: 0.55430543 train ndcg: 0.9460955919801707
# Time: 6.358654022216797 seconds
# Time cumulative: 395.1261920928955 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 32288.304688
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 48 test rmse: 0.8915893 test mae: 0.69691765 test ndcg: 0.9047890157116534
# Epoch: 48 test TP: 15167 test FP 836129
# Epoch: 48 train rmse: 0.7066119 train mae: 0.55347556 train ndcg: 0.9464043016900928
# Time: 5.857288599014282 seconds
# Time cumulative: 400.9834806919098 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 32217.792969
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 49 test rmse: 0.89164025 test mae: 0.6971168 test ndcg: 0.9048214779709237
# Epoch: 49 test TP: 15164 test FP 836210
# Epoch: 49 train rmse: 0.7056302 train mae: 0.55271727 train ndcg: 0.9465676462092951
# Time: 5.658684015274048 seconds
# Time cumulative: 406.64216470718384 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 32104.451172
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 50 test rmse: 0.8921985 test mae: 0.6977872 test ndcg: 0.9047935001175987
# Epoch: 50 test TP: 15153 test FP 834119
# Epoch: 50 train rmse: 0.70436484 train mae: 0.55212575 train ndcg: 0.9469285782181723
# Time: 5.750498533248901 seconds
# Time cumulative: 412.39266324043274 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 32023.894531
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 51 test rmse: 0.8918896 test mae: 0.6968821 test ndcg: 0.9050194661110981
# Epoch: 51 test TP: 15181 test FP 835476
# Epoch: 51 train rmse: 0.7032923 train mae: 0.5507086 train ndcg: 0.9470498894272282
# Time: 5.642053842544556 seconds
# Time cumulative: 418.0347170829773 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 31921.595703
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 52 test rmse: 0.8914465 test mae: 0.6965857 test ndcg: 0.905253520894529
# Epoch: 52 test TP: 15207 test FP 837414
# Epoch: 52 train rmse: 0.7018015 train mae: 0.5492474 train ndcg: 0.9471693511753344
# Time: 5.337159633636475 seconds
# Time cumulative: 423.37187671661377 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 31851.337891
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 53 test rmse: 0.8911477 test mae: 0.6962514 test ndcg: 0.9047783171276726
# Epoch: 53 test TP: 15223 test FP 838412
# Epoch: 53 train rmse: 0.70086426 train mae: 0.54839534 train ndcg: 0.9474263729767708
# Time: 5.684982776641846 seconds
# Time cumulative: 429.0568594932556 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 31791.341797
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 54 test rmse: 0.89127964 test mae: 0.6963588 test ndcg: 0.9047381715651959
# Epoch: 54 test TP: 15227 test FP 838141
# Epoch: 54 train rmse: 0.7000537 train mae: 0.5477523 train ndcg: 0.9476377025432678
# Time: 5.5524561405181885 seconds
# Time cumulative: 434.6093156337738 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 31684.265625
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 55 test rmse: 0.8911222 test mae: 0.69610924 test ndcg: 0.904573651957106
# Epoch: 55 test TP: 15218 test FP 839066
# Epoch: 55 train rmse: 0.6987648 train mae: 0.54678047 train ndcg: 0.9479542838878401
# Time: 5.499064683914185 seconds
# Time cumulative: 440.108380317688 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 31613.648438
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 56 test rmse: 0.892216 test mae: 0.69732976 test ndcg: 0.9052923642605615
# Epoch: 56 test TP: 15180 test FP 833031
# Epoch: 56 train rmse: 0.69792324 train mae: 0.546362 train ndcg: 0.9482140102241798
# Time: 6.09035849571228 seconds
# Time cumulative: 446.19873881340027 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 31525.021484
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 57 test rmse: 0.8916842 test mae: 0.69664013 test ndcg: 0.9052487594517223
# Epoch: 57 test TP: 15172 test FP 832696
# Epoch: 57 train rmse: 0.69651854 train mae: 0.54517883 train ndcg: 0.9480840875025599
# Time: 6.255509376525879 seconds
# Time cumulative: 452.45424818992615 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 31450.144531
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 58 test rmse: 0.8915489 test mae: 0.6964761 test ndcg: 0.9049611556574648
# Epoch: 58 test TP: 15186 test FP 834312
# Epoch: 58 train rmse: 0.6954459 train mae: 0.5441388 train ndcg: 0.9486301440176168
# Time: 5.670685291290283 seconds
# Time cumulative: 458.12493348121643 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 31357.560547
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 59 test rmse: 0.8923874 test mae: 0.6974256 test ndcg: 0.9048734186110581
# Epoch: 59 test TP: 15165 test FP 830824
# Epoch: 59 train rmse: 0.69433 train mae: 0.54357827 train ndcg: 0.9486818351972623
# Time: 6.713235378265381 seconds
# Time cumulative: 464.8381688594818 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   Objective function value: 31282.537109
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 60 test rmse: 0.8922146 test mae: 0.6972668 test ndcg: 0.9053382596541919
# Epoch: 60 test TP: 15155 test FP 830051
# Epoch: 60 train rmse: 0.6931517 train mae: 0.5427101 train ndcg: 0.9489281957916069
# Time: 5.82800555229187 seconds
# Time cumulative: 470.6661744117737 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._

# %%
# Final result
print('Epoch:', best_rmse_ep, ' best rmse:', best_rmse)
print('Epoch:', best_mae_ep, ' best mae:', best_mae)
print('Epoch:', best_ndcg_ep, ' best ndcg:', best_ndcg)
print('Epoch:', best_TP_ep, ' best TP:', best_TP)
print('Epoch:', best_FP_ep, ' best FP:', best_FP)
# Out:
# Epoch: 35  best rmse: 0.8908744
# Epoch: 55  best mae: 0.69610924
# Epoch: 60  best ndcg: 0.9053382596541919
# Epoch: 1  best TP: 15638
# Epoch: 60  best FP: 830051
